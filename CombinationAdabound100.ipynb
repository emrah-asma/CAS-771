# %%
# set Keras backend to Tensorflow
import os
import tensorflow as tf

os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %%
# import
import keras
from keras.models import load_model
from keras_adabound import AdaBound
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, InputLayer
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
import os
import pickle
import numpy as np

# %%
# make saving directory
saveDir = "./cifar10/combAda100/"
if not os.path.isdir(saveDir):
    os.makedirs(saveDir)

# %%
# get Cifar10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('x train shape:', x_train.shape)
print(x_train.shape[0], 'training images')
print(x_test.shape[0], 'test images')
# Out:
# x train shape: (50000, 32, 32, 3)
# 50000 training images
# 10000 test images

# %%
from keras.utils import np_utils
# prerequisite
num_classes = 10
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
initNum = 10000
x_train1 = x_train[:initNum]
y_train1 = y_train[:initNum]
remainXTrain = x_train[initNum:]
remainYTrain = y_train[initNum:]

# %%
print("initial training X: {0}\n\
initial training Y: {1}\n\
remaining training X: {2}\n\
remaining training Y: {3}\n\
test X: {4}\n\
test Y: {5}".format(
    x_train1.shape,y_train1.shape,remainXTrain.shape,remainYTrain.shape,x_test.shape,y_test.shape))
# Out:
# initial training X: (10000, 32, 32, 3)
# initial training Y: (10000, 10)
# remaining training X: (40000, 32, 32, 3)
# remaining training Y: (40000, 10)
# test X: (10000, 32, 32, 3)
# test Y: (10000, 10)

# %%
labels = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
from keras_adabound import AdaBound

# optimization and compile
def compileModel(model, lr=1e-3, decay=0.1):
    opt = AdaBound(learning_rate=lr, final_lr=decay)

    model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=['accuracy'])
   
    return model

# %%
# define layers
def getModel(loadModel=False, modelFilePath="", lr=0.001, decay=1e-6):
    model = Sequential()
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    
    model = compileModel(model)
    
    # load model weights if specified
    if loadModel == True:
        model.load_weights(modelFilePath)
    
    return model

# %%
# get the newest model file
def getNewestModel(dirname=saveDir):
    import os
    from glob import glob
    target = os.path.join(dirname, '*')
    files = [(f, os.path.getmtime(f)) for f in glob(target)]
    if len(files) == 0:
        return getModel()
    else:
        newestModel = sorted(files, key=lambda files: files[1])[-1]
        return getModel(True, newestModel[0])

# %%
# get the CNN model
model = getModel()

# %%
# train the model
def trainModel(model, xTrain, yTrain, xTest, yTest, batch_size=50, epochs=100, patience=1):
    es_cb = EarlyStopping(monitor='val_loss', patience=patience, verbose=1, mode='auto')
    chkpt = os.path.join(saveDir, 'Cifar10_.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5')
    cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

    # train
    model.fit(xTrain, yTrain,
              batch_size=batch_size,
              epochs=epochs,
              verbose=0,
              validation_data=(xTest, yTest),
              callbacks=[es_cb, cp_cb],
              shuffle=True)
    return model

# %%
# run training on the initial dataset

model = trainModel(model, x_train1, y_train1, x_test, y_test, patience=2)
# Out:
# Epoch 1: val_loss improved from inf to 1.81120, saving model to ./cifar10/combAda100\Cifar10_.01-1.98-1.81.hdf5
#
# Epoch 2: val_loss improved from 1.81120 to 1.59121, saving model to ./cifar10/combAda100\Cifar10_.02-1.73-1.59.hdf5
#
# Epoch 3: val_loss did not improve from 1.59121

# %%
# use the pre-trained model, with 65% accuracy on test data

model.load_weights("")

# %%
# define evaluation method
def evaluate(model, xTest, yTest, display=False):
    # only shows loss and accuracy
    if display == False:
        ev = model.evaluate(xTest, yTest, verbose=0)
        return ev
    # shows confusion matrix, classification report and accuracy score
    else:
        import pandas as pd
        import seaborn as sn
        import matplotlib.pyplot as plt
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import classification_report, accuracy_score

        def toNum(y):
            yNum = []
            for x in y:
                yNum.append(x.argmax())
            return np.array(yNum)

        # visualize confusion matrix on heat map
        def print_cmx(y_true, y_pred):
            labels = sorted(list(set(y_true)))
            cmx_data = confusion_matrix(y_true, y_pred, labels=labels)

            df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)

            plt.figure(figsize = (10,7))
            sn.heatmap(df_cmx, annot=True)
            plt.show()

        # reshape testing target to fit to scikit-learn metric form
        y_testPred = model.predict(xTest)
        y_testP = toNum(y_testPred)
        y_true = toNum(yTest)

        # get confusion matrix, classification report and accuracy score
        print_cmx(y_true, y_testP)
        print(classification_report(y_true, y_testP))
        print("Accuracy: {0}".format(accuracy_score(y_true, y_testP)))

# %%
# evaluate the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59      1000
#            1       0.72      0.65      0.68      1000
#            2       0.38      0.43      0.40      1000
#            3       0.39      0.32      0.35      1000
#            4       0.60      0.21      0.31      1000
#            5       0.38      0.62      0.47      1000
#            6       0.53      0.69      0.60      1000
#            7       0.67      0.51      0.58      1000
#            8       0.65      0.70      0.67      1000
#            9       0.59      0.67      0.63      1000
#
#     accuracy                           0.54     10000
#    macro avg       0.55      0.54      0.53     10000
# weighted avg       0.55      0.54      0.53     10000
#
# Accuracy: 0.5356

# %%
# record the loss and accuracy
evalHistory = []
evalHistory.append(evaluate(model, x_test, y_test, display=False))
print(evalHistory[-1])
# Out:
# [1.2776650190353394, 0.5356000065803528]

# %%
# get a list of low margin inference
def getLowMargin(proba, bound=0.01):
    ls = []
    for i in range(len(proba)):
        margin = proba[i][np.argsort(proba[i])][-1] - proba[i][np.argsort(proba[i])][-2]
        if margin < bound:
            ls.append([i,margin])
    return ls

# %%
# get a list of high probability inference
def getHighProb(proba, bound):
    ls = []
    for i in range(len(proba)):
        for p in range(len(proba[i])):
            if proba[i,p] > bound:
                ls.append([i,p])
    return ls

# %%
from keras.utils import np_utils
# concatenate initial training data with low margin of 1st and 2nd choice inference and high probability
# removing them from remaining data
def concatData(proba, remainX, remainY, xTrain, yTrain, Lbound=0.01, Hbound=0.99):
    lm = getLowMargin(proba, Lbound)
    print("number of data with first and second choice probability lower than {0}: {1}".format(Lbound,len(lm)))
    hp = getHighProb(proba, Hbound)
    print("number of data with probability higher than {0}: {1}".format(Hbound,len(hp)))
    
    nlm = np.array(np.array(lm)[:,0], dtype="int32")
    lxAdd = remainX[nlm]
    lyAdd = remainY[nlm]
    print("x shape to be added from low margin: {0}\ny shape to be added: {1}".format(lxAdd.shape, lyAdd.shape))
    
    nhp = np.array(hp)
    hxAdd = remainX[nhp[:,0]]
    hyAdd = np.array([nhp[:,1]]).T
    hyAdd = keras.utils.np_utils.to_categorical(hyAdd, num_classes)
    yActual = remainY[nhp[:,0]]
    print("x shape to be added from high probability: {0}\ny shape to be added: {1}".format(hxAdd.shape, hyAdd.shape))
    
    ixAdd = np.vstack((lxAdd, hxAdd))
    iyAdd = np.vstack((lyAdd, hyAdd))
    nlmhp = np.hstack((nhp[:,0],nlm))
    
    NewXTrain = np.vstack((xTrain, ixAdd))
    NewYTrain = np.vstack((yTrain, iyAdd))
    print("new training data:\n\tx: {0}\n\ty: {1}".format(NewXTrain.shape, NewYTrain.shape))
    
    remainX2 = np.delete(remainX, nlmhp, axis=0)
    remainY2 = np.delete(remainY, nlmhp, axis=0)
    print("remaining data:\n\tx: {0}\n\ty: {1}".format(remainX2.shape, remainY2.shape))
        
    yEval = [[yActual[i],hyAdd[i]] for i in range(len(hyAdd))]
    
    return remainX2, remainY2, NewXTrain, NewYTrain, yEval

# %%
def getError(yEval):
    errLabel = [0]*10
    for i in range(len(yEval)):
        if False in (yEval[i][0] == yEval[i][1]):
            errLabel[np.argmax(yEval[i][0]-yEval[i][1])] += 1
    return errLabel

# %%
# proba = model.predict_proba(remainXTrain, verbose=0)
proba=model.predict(remainXTrain,verbose=0)

# %%
# get new training data from high probability
remainXTrain, remainYTrain, x_train2, y_train2, yEval= concatData(proba, 
                                                                  remainXTrain, 
                                                                  remainYTrain, 
                                                                  x_train1, 
                                                                  y_train1, 
                                                                  0.01,
                                                                  0.9999)
errPred = getError(yEval)
# Out:
# number of data with first and second choice probability lower than 0.01: 1366
# number of data with probability higher than 0.9999: 0
# x shape to be added from low margin: (1366, 32, 32, 3)
# y shape to be added: (1366, 10)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 # get new training data from high probability
# ----> 2 remainXTrain, remainYTrain, x_train2, y_train2, yEval= concatData(proba,
#       3                                                                   remainXTrain,
#       4                                                                   remainYTrain,
#       5                                                                   x_train1,
#       6                                                                   y_train1,
#       7                                                                   0.01,
#       8                                                                   0.9999)
#       9 errPred = getError(yEval)
#
# Input In [21], in concatData(proba, remainX, remainY, xTrain, yTrain, Lbound, Hbound)
#      13 print("x shape to be added from low margin: {0}\ny shape to be added: {1}".format(lxAdd.shape, lyAdd.shape))
#      15 nhp = np.array(hp)
# ---> 16 hxAdd = remainX[nhp[:,0]]
#      17 hyAdd = np.array([nhp[:,1]]).T
#      18 hyAdd = keras.utils.np_utils.to_categorical(hyAdd, num_classes)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# retrain the model
model = trainModel(model, x_train2, y_train2, x_test, y_test)
# Out:
# Epoch 1: val_loss improved from inf to 1.07431, saving model to ./cifar10/combAda\Cifar10_.01-0.99-1.07.hdf5
#
# Epoch 2: val_loss improved from 1.07431 to 1.06745, saving model to ./cifar10/combAda\Cifar10_.02-0.92-1.07.hdf5
#
# Epoch 3: val_loss improved from 1.06745 to 1.06217, saving model to ./cifar10/combAda\Cifar10_.03-0.87-1.06.hdf5
#
# Epoch 4: val_loss improved from 1.06217 to 1.03544, saving model to ./cifar10/combAda\Cifar10_.04-0.82-1.04.hdf5
#
# Epoch 5: val_loss did not improve from 1.03544
# Epoch 5: early stopping

# %%
# load the newest checkpoint model to get the best accuracy one
model = getNewestModel()

# %%
# evaluate with the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68      1000
#            1       0.78      0.83      0.81      1000
#            2       0.57      0.37      0.45      1000
#            3       0.47      0.40      0.43      1000
#            4       0.54      0.59      0.57      1000
#            5       0.54      0.56      0.55      1000
#            6       0.58      0.81      0.68      1000
#            7       0.78      0.65      0.71      1000
#            8       0.80      0.68      0.73      1000
#            9       0.75      0.77      0.76      1000
#
#     accuracy                           0.64     10000
#    macro avg       0.64      0.64      0.64     10000
# weighted avg       0.64      0.64      0.64     10000
#
# Accuracy: 0.6404

# %%
# record the loss and accuracy
evalHistory.append(evaluate(model, x_test, y_test, display=False))
print(evalHistory[-1])
# Out:
# [1.035438060760498, 0.6403999924659729]

# %%
for i in range(100):
    #proba = model.predict_proba(remainXTrain, verbose=0)
    proba=model.predict(remainXTrain,verbose=0)
    # get new training data from high probability
    remainXTrain, remainYTrain, x_train2, y_train2, yEval= concatData(proba, 
                                                                      remainXTrain, 
                                                                      remainYTrain, 
                                                                      x_train2, 
                                                                      y_train2, 
                                                                      0.01,
                                                                      0.9999)
    errPred2 = getError(yEval)
    errPred = [errPred2[i]+errPred[i] for i in range(len(errPred))]
    model = trainModel(model, x_train2, y_train2, x_test, y_test)
    model = getNewestModel()
    evalHistory.append(evaluate(model, x_test, y_test, display=False))
    print("\nAfter Iter: {0}\n\tLoss and Acc: {1}\n".format(i,evalHistory[-1]))
# Out:
# number of data with first and second choice probability lower than 0.01: 673
# number of data with probability higher than 0.9999: 181
# x shape to be added from low margin: (673, 32, 32, 3)
# y shape to be added: (673, 10)
# x shape to be added from high probability: (181, 32, 32, 3)
# y shape to be added: (181, 10)
# new training data:
# 	x: (11725, 32, 32, 3)
# 	y: (11725, 10)
# remaining data:
# 	x: (38275, 32, 32, 3)
# 	y: (38275, 10)
#
# Epoch 1: val_loss improved from inf to 0.99540, saving model to ./cifar10/combAda\Cifar10_.01-0.92-1.00.hdf5
#
# Epoch 2: val_loss improved from 0.99540 to 0.98993, saving model to ./cifar10/combAda\Cifar10_.02-0.76-0.99.hdf5
#
# Epoch 3: val_loss did not improve from 0.98993
# Epoch 3: early stopping
#
# After Iter: 0
# 	Loss and Acc: [0.9899290204048157, 0.6611999869346619]
#
# number of data with first and second choice probability lower than 0.01: 542
# number of data with probability higher than 0.9999: 281
# x shape to be added from low margin: (542, 32, 32, 3)
# y shape to be added: (542, 10)
# x shape to be added from high probability: (281, 32, 32, 3)
# y shape to be added: (281, 10)
# new training data:
# 	x: (12548, 32, 32, 3)
# 	y: (12548, 10)
# remaining data:
# 	x: (37452, 32, 32, 3)
# 	y: (37452, 10)
#
# Epoch 1: val_loss improved from inf to 0.98434, saving model to ./cifar10/combAda\Cifar10_.01-0.77-0.98.hdf5
#
# Epoch 2: val_loss improved from 0.98434 to 0.97261, saving model to ./cifar10/combAda\Cifar10_.02-0.63-0.97.hdf5
#
# Epoch 3: val_loss did not improve from 0.97261
# Epoch 3: early stopping
#
# After Iter: 1
# 	Loss and Acc: [0.9726123213768005, 0.6740000247955322]
#
# number of data with first and second choice probability lower than 0.01: 429
# number of data with probability higher than 0.9999: 697
# x shape to be added from low margin: (429, 32, 32, 3)
# y shape to be added: (429, 10)
# x shape to be added from high probability: (697, 32, 32, 3)
# y shape to be added: (697, 10)
# new training data:
# 	x: (13674, 32, 32, 3)
# 	y: (13674, 10)
# remaining data:
# 	x: (36326, 32, 32, 3)
# 	y: (36326, 10)
#
# Epoch 1: val_loss improved from inf to 0.95313, saving model to ./cifar10/combAda\Cifar10_.01-0.63-0.95.hdf5
#
# Epoch 2: val_loss did not improve from 0.95313
# Epoch 2: early stopping
#
# After Iter: 2
# 	Loss and Acc: [0.953132688999176, 0.6865000128746033]
#
# number of data with first and second choice probability lower than 0.01: 402
# number of data with probability higher than 0.9999: 261
# x shape to be added from low margin: (402, 32, 32, 3)
# y shape to be added: (402, 10)
# x shape to be added from high probability: (261, 32, 32, 3)
# y shape to be added: (261, 10)
# new training data:
# 	x: (14337, 32, 32, 3)
# 	y: (14337, 10)
# remaining data:
# 	x: (35663, 32, 32, 3)
# 	y: (35663, 10)
#
# Epoch 1: val_loss improved from inf to 1.02106, saving model to ./cifar10/combAda\Cifar10_.01-0.60-1.02.hdf5
#
# Epoch 2: val_loss improved from 1.02106 to 1.00824, saving model to ./cifar10/combAda\Cifar10_.02-0.46-1.01.hdf5
#
# Epoch 3: val_loss did not improve from 1.00824
# Epoch 3: early stopping
#
# After Iter: 3
# 	Loss and Acc: [1.008242130279541, 0.6935999989509583]
#
# number of data with first and second choice probability lower than 0.01: 282
# number of data with probability higher than 0.9999: 1979
# x shape to be added from low margin: (282, 32, 32, 3)
# y shape to be added: (282, 10)
# x shape to be added from high probability: (1979, 32, 32, 3)
# y shape to be added: (1979, 10)
# new training data:
# 	x: (16598, 32, 32, 3)
# 	y: (16598, 10)
# remaining data:
# 	x: (33402, 32, 32, 3)
# 	y: (33402, 10)
#
# Epoch 1: val_loss improved from inf to 1.04799, saving model to ./cifar10/combAda\Cifar10_.01-0.44-1.05.hdf5
#
# Epoch 2: val_loss did not improve from 1.04799
# Epoch 2: early stopping
#
# After Iter: 4
# 	Loss and Acc: [1.047991156578064, 0.6868000030517578]
#
# number of data with first and second choice probability lower than 0.01: 283
# number of data with probability higher than 0.9999: 731
# x shape to be added from low margin: (283, 32, 32, 3)
# y shape to be added: (283, 10)
# x shape to be added from high probability: (731, 32, 32, 3)
# y shape to be added: (731, 10)
# new training data:
# 	x: (17612, 32, 32, 3)
# 	y: (17612, 10)
# remaining data:
# 	x: (32388, 32, 32, 3)
# 	y: (32388, 10)
#
# Epoch 1: val_loss improved from inf to 1.00536, saving model to ./cifar10/combAda\Cifar10_.01-0.42-1.01.hdf5
#
# Epoch 2: val_loss did not improve from 1.00536
# Epoch 2: early stopping
#
# After Iter: 5
# 	Loss and Acc: [1.0053608417510986, 0.6909000277519226]
#
# number of data with first and second choice probability lower than 0.01: 304
# number of data with probability higher than 0.9999: 427
# x shape to be added from low margin: (304, 32, 32, 3)
# y shape to be added: (304, 10)
# x shape to be added from high probability: (427, 32, 32, 3)
# y shape to be added: (427, 10)
# new training data:
# 	x: (18343, 32, 32, 3)
# 	y: (18343, 10)
# remaining data:
# 	x: (31657, 32, 32, 3)
# 	y: (31657, 10)
#
# Epoch 1: val_loss improved from inf to 0.97830, saving model to ./cifar10/combAda\Cifar10_.01-0.40-0.98.hdf5
#
# Epoch 2: val_loss did not improve from 0.97830
# Epoch 2: early stopping
#
# After Iter: 6
# 	Loss and Acc: [0.9783000946044922, 0.6984999775886536]
#
# number of data with first and second choice probability lower than 0.01: 292
# number of data with probability higher than 0.9999: 447
# x shape to be added from low margin: (292, 32, 32, 3)
# y shape to be added: (292, 10)
# x shape to be added from high probability: (447, 32, 32, 3)
# y shape to be added: (447, 10)
# new training data:
# 	x: (19082, 32, 32, 3)
# 	y: (19082, 10)
# remaining data:
# 	x: (30918, 32, 32, 3)
# 	y: (30918, 10)
#
# Epoch 1: val_loss improved from inf to 0.99090, saving model to ./cifar10/combAda\Cifar10_.01-0.38-0.99.hdf5
#
# Epoch 2: val_loss did not improve from 0.99090
# Epoch 2: early stopping
#
# After Iter: 7
# 	Loss and Acc: [0.9908956289291382, 0.6966000199317932]
#
# number of data with first and second choice probability lower than 0.01: 278
# number of data with probability higher than 0.9999: 547
# x shape to be added from low margin: (278, 32, 32, 3)
# y shape to be added: (278, 10)
# x shape to be added from high probability: (547, 32, 32, 3)
# y shape to be added: (547, 10)
# new training data:
# 	x: (19907, 32, 32, 3)
# 	y: (19907, 10)
# remaining data:
# 	x: (30093, 32, 32, 3)
# 	y: (30093, 10)
#
# Epoch 1: val_loss improved from inf to 1.06503, saving model to ./cifar10/combAda\Cifar10_.01-0.37-1.07.hdf5
#
# Epoch 2: val_loss did not improve from 1.06503
# Epoch 2: early stopping
#
# After Iter: 8
# 	Loss and Acc: [1.0650322437286377, 0.6819000244140625]
#
# number of data with first and second choice probability lower than 0.01: 270
# number of data with probability higher than 0.9999: 305
# x shape to be added from low margin: (270, 32, 32, 3)
# y shape to be added: (270, 10)
# x shape to be added from high probability: (305, 32, 32, 3)
# y shape to be added: (305, 10)
# new training data:
# 	x: (20482, 32, 32, 3)
# 	y: (20482, 10)
# remaining data:
# 	x: (29518, 32, 32, 3)
# 	y: (29518, 10)
#
# Epoch 1: val_loss improved from inf to 1.00115, saving model to ./cifar10/combAda\Cifar10_.01-0.34-1.00.hdf5
#
# Epoch 2: val_loss did not improve from 1.00115
# Epoch 2: early stopping
#
# After Iter: 9
# 	Loss and Acc: [1.001145839691162, 0.7045999765396118]
#
# number of data with first and second choice probability lower than 0.01: 228
# number of data with probability higher than 0.9999: 563
# x shape to be added from low margin: (228, 32, 32, 3)
# y shape to be added: (228, 10)
# x shape to be added from high probability: (563, 32, 32, 3)
# y shape to be added: (563, 10)
# new training data:
# 	x: (21273, 32, 32, 3)
# 	y: (21273, 10)
# remaining data:
# 	x: (28727, 32, 32, 3)
# 	y: (28727, 10)
#
# Epoch 1: val_loss improved from inf to 1.00643, saving model to ./cifar10/combAda\Cifar10_.01-0.32-1.01.hdf5
#
# Epoch 2: val_loss did not improve from 1.00643
# Epoch 2: early stopping
#
# After Iter: 10
# 	Loss and Acc: [1.0064294338226318, 0.7046999931335449]
#
# number of data with first and second choice probability lower than 0.01: 224
# number of data with probability higher than 0.9999: 626
# x shape to be added from low margin: (224, 32, 32, 3)
# y shape to be added: (224, 10)
# x shape to be added from high probability: (626, 32, 32, 3)
# y shape to be added: (626, 10)
# new training data:
# 	x: (22123, 32, 32, 3)
# 	y: (22123, 10)
# remaining data:
# 	x: (27877, 32, 32, 3)
# 	y: (27877, 10)
# Epoch 1: val_loss improved from inf to 0.99854, saving model to ./cifar10/combAda\Cifar10_.01-0.30-1.00.hdf5
#
# Epoch 2: val_loss did not improve from 0.99854
# Epoch 2: early stopping
#
# After Iter: 11
# 	Loss and Acc: [0.9985401630401611, 0.7075999975204468]
#
# number of data with first and second choice probability lower than 0.01: 203
# number of data with probability higher than 0.9999: 660
# x shape to be added from low margin: (203, 32, 32, 3)
# y shape to be added: (203, 10)
# x shape to be added from high probability: (660, 32, 32, 3)
# y shape to be added: (660, 10)
# new training data:
# 	x: (22986, 32, 32, 3)
# 	y: (22986, 10)
# remaining data:
# 	x: (27014, 32, 32, 3)
# 	y: (27014, 10)
#
# Epoch 1: val_loss improved from inf to 0.98828, saving model to ./cifar10/combAda\Cifar10_.01-0.29-0.99.hdf5
#
# Epoch 2: val_loss did not improve from 0.98828
# Epoch 2: early stopping
#
# After Iter: 12
# 	Loss and Acc: [0.9882855415344238, 0.7093999981880188]
#
# number of data with first and second choice probability lower than 0.01: 199
# number of data with probability higher than 0.9999: 396
# x shape to be added from low margin: (199, 32, 32, 3)
# y shape to be added: (199, 10)
# x shape to be added from high probability: (396, 32, 32, 3)
# y shape to be added: (396, 10)
# new training data:
# 	x: (23581, 32, 32, 3)
# 	y: (23581, 10)
# remaining data:
# 	x: (26419, 32, 32, 3)
# 	y: (26419, 10)
#
# Epoch 1: val_loss improved from inf to 1.08954, saving model to ./cifar10/combAda\Cifar10_.01-0.28-1.09.hdf5
#
# Epoch 2: val_loss improved from 1.08954 to 1.01735, saving model to ./cifar10/combAda\Cifar10_.02-0.23-1.02.hdf5
#
# Epoch 3: val_loss did not improve from 1.01735
# Epoch 3: early stopping
#
# After Iter: 13
# 	Loss and Acc: [1.017346978187561, 0.7142999768257141]
#
# number of data with first and second choice probability lower than 0.01: 176
# number of data with probability higher than 0.9999: 670
# x shape to be added from low margin: (176, 32, 32, 3)
# y shape to be added: (176, 10)
# x shape to be added from high probability: (670, 32, 32, 3)
# y shape to be added: (670, 10)
# new training data:
# 	x: (24427, 32, 32, 3)
# 	y: (24427, 10)
# remaining data:
# 	x: (25573, 32, 32, 3)
# 	y: (25573, 10)
#
# Epoch 1: val_loss improved from inf to 1.09905, saving model to ./cifar10/combAda\Cifar10_.01-0.26-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.09905
# Epoch 2: early stopping
#
# After Iter: 14
# 	Loss and Acc: [1.0990476608276367, 0.7138000130653381]
#
# number of data with first and second choice probability lower than 0.01: 146
# number of data with probability higher than 0.9999: 1045
# x shape to be added from low margin: (146, 32, 32, 3)
# y shape to be added: (146, 10)
# x shape to be added from high probability: (1045, 32, 32, 3)
# y shape to be added: (1045, 10)
# new training data:
# 	x: (25618, 32, 32, 3)
# 	y: (25618, 10)
# remaining data:
# 	x: (24382, 32, 32, 3)
# 	y: (24382, 10)
#
# Epoch 1: val_loss improved from inf to 1.06578, saving model to ./cifar10/combAda\Cifar10_.01-0.24-1.07.hdf5
#
# Epoch 2: val_loss did not improve from 1.06578
# Epoch 2: early stopping
#
# After Iter: 15
# 	Loss and Acc: [1.0657821893692017, 0.7192999720573425]
#
# number of data with first and second choice probability lower than 0.01: 145
# number of data with probability higher than 0.9999: 523
# x shape to be added from low margin: (145, 32, 32, 3)
# y shape to be added: (145, 10)
# x shape to be added from high probability: (523, 32, 32, 3)
# y shape to be added: (523, 10)
# new training data:
# 	x: (26286, 32, 32, 3)
# 	y: (26286, 10)
# remaining data:
# 	x: (23714, 32, 32, 3)
# 	y: (23714, 10)
#
# Epoch 1: val_loss improved from inf to 1.09816, saving model to ./cifar10/combAda\Cifar10_.01-0.24-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.09816
# Epoch 2: early stopping
#
# After Iter: 16
# 	Loss and Acc: [1.0981545448303223, 0.7148000001907349]
#
# number of data with first and second choice probability lower than 0.01: 140
# number of data with probability higher than 0.9999: 541
# x shape to be added from low margin: (140, 32, 32, 3)
# y shape to be added: (140, 10)
# x shape to be added from high probability: (541, 32, 32, 3)
# y shape to be added: (541, 10)
# new training data:
# 	x: (26967, 32, 32, 3)
# 	y: (26967, 10)
# remaining data:
# 	x: (23033, 32, 32, 3)
# 	y: (23033, 10)
#
# Epoch 1: val_loss improved from inf to 0.98555, saving model to ./cifar10/combAda\Cifar10_.01-0.23-0.99.hdf5
#
# Epoch 2: val_loss did not improve from 0.98555
# Epoch 2: early stopping
#
# After Iter: 17
# 	Loss and Acc: [0.9855484366416931, 0.7149999737739563]
#
# number of data with first and second choice probability lower than 0.01: 174
# number of data with probability higher than 0.9999: 191
# x shape to be added from low margin: (174, 32, 32, 3)
# y shape to be added: (174, 10)
# x shape to be added from high probability: (191, 32, 32, 3)
# y shape to be added: (191, 10)
# new training data:
# 	x: (27332, 32, 32, 3)
# 	y: (27332, 10)
# remaining data:
# 	x: (22668, 32, 32, 3)
# 	y: (22668, 10)
#
# Epoch 1: val_loss improved from inf to 1.05123, saving model to ./cifar10/combAda\Cifar10_.01-0.24-1.05.hdf5
#
# Epoch 2: val_loss did not improve from 1.05123
# Epoch 2: early stopping
#
# After Iter: 18
# 	Loss and Acc: [1.0512315034866333, 0.7196000218391418]
#
# number of data with first and second choice probability lower than 0.01: 136
# number of data with probability higher than 0.9999: 361
# x shape to be added from low margin: (136, 32, 32, 3)
# y shape to be added: (136, 10)
# x shape to be added from high probability: (361, 32, 32, 3)
# y shape to be added: (361, 10)
# new training data:
# 	x: (27829, 32, 32, 3)
# 	y: (27829, 10)
# remaining data:
# 	x: (22171, 32, 32, 3)
# 	y: (22171, 10)
#
# Epoch 1: val_loss improved from inf to 1.08708, saving model to ./cifar10/combAda\Cifar10_.01-0.23-1.09.hdf5
#
# Epoch 2: val_loss did not improve from 1.08708
# Epoch 2: early stopping
#
# After Iter: 19
# 	Loss and Acc: [1.0870832204818726, 0.722599983215332]
#
# number of data with first and second choice probability lower than 0.01: 131
# number of data with probability higher than 0.9999: 641
# x shape to be added from low margin: (131, 32, 32, 3)
# y shape to be added: (131, 10)
# x shape to be added from high probability: (641, 32, 32, 3)
# y shape to be added: (641, 10)
# new training data:
# 	x: (28601, 32, 32, 3)
# 	y: (28601, 10)
# remaining data:
# 	x: (21399, 32, 32, 3)
# 	y: (21399, 10)
#
# Epoch 1: val_loss improved from inf to 1.54531, saving model to ./cifar10/combAda\Cifar10_.01-0.23-1.55.hdf5
#
# Epoch 2: val_loss improved from 1.54531 to 1.12390, saving model to ./cifar10/combAda\Cifar10_.02-0.33-1.12.hdf5
#
# Epoch 3: val_loss did not improve from 1.12390
# Epoch 3: early stopping
#
# After Iter: 20
# 	Loss and Acc: [1.123898983001709, 0.7099999785423279]
#
# number of data with first and second choice probability lower than 0.01: 145
# number of data with probability higher than 0.9999: 560
# x shape to be added from low margin: (145, 32, 32, 3)
# y shape to be added: (145, 10)
# x shape to be added from high probability: (560, 32, 32, 3)
# y shape to be added: (560, 10)
# new training data:
# 	x: (29306, 32, 32, 3)
# 	y: (29306, 10)
# remaining data:
# 	x: (20694, 32, 32, 3)
# 	y: (20694, 10)
#
# Epoch 1: val_loss improved from inf to 1.11018, saving model to ./cifar10/combAda\Cifar10_.01-0.23-1.11.hdf5
#
# Epoch 2: val_loss improved from 1.11018 to 1.09538, saving model to ./cifar10/combAda\Cifar10_.02-0.21-1.10.hdf5
#
# Epoch 3: val_loss did not improve from 1.09538
# Epoch 3: early stopping
#
# After Iter: 21
# 	Loss and Acc: [1.0953763723373413, 0.7174000144004822]
#
# number of data with first and second choice probability lower than 0.01: 141
# number of data with probability higher than 0.9999: 562
# x shape to be added from low margin: (141, 32, 32, 3)
# y shape to be added: (141, 10)
# x shape to be added from high probability: (562, 32, 32, 3)
# y shape to be added: (562, 10)
# new training data:
# 	x: (30009, 32, 32, 3)
# 	y: (30009, 10)
# remaining data:
# 	x: (19991, 32, 32, 3)
# 	y: (19991, 10)
#
# Epoch 1: val_loss improved from inf to 1.09750, saving model to ./cifar10/combAda\Cifar10_.01-0.21-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.09750
# Epoch 2: early stopping
#
# After Iter: 22
# 	Loss and Acc: [1.0975017547607422, 0.7206000089645386]
#
# number of data with first and second choice probability lower than 0.01: 123
# number of data with probability higher than 0.9999: 467
# x shape to be added from low margin: (123, 32, 32, 3)
# y shape to be added: (123, 10)
# x shape to be added from high probability: (467, 32, 32, 3)
# y shape to be added: (467, 10)
# new training data:
# 	x: (30599, 32, 32, 3)
# 	y: (30599, 10)
# remaining data:
# 	x: (19401, 32, 32, 3)
# 	y: (19401, 10)
# Epoch 1: val_loss improved from inf to 1.09448, saving model to ./cifar10/combAda\Cifar10_.01-0.22-1.09.hdf5
#
# Epoch 2: val_loss did not improve from 1.09448
# Epoch 2: early stopping
#
# After Iter: 23
# 	Loss and Acc: [1.0944783687591553, 0.7213000059127808]
#
# number of data with first and second choice probability lower than 0.01: 139
# number of data with probability higher than 0.9999: 329
# x shape to be added from low margin: (139, 32, 32, 3)
# y shape to be added: (139, 10)
# x shape to be added from high probability: (329, 32, 32, 3)
# y shape to be added: (329, 10)
# new training data:
# 	x: (31067, 32, 32, 3)
# 	y: (31067, 10)
# remaining data:
# 	x: (18933, 32, 32, 3)
# 	y: (18933, 10)
#
# Epoch 1: val_loss improved from inf to 1.04205, saving model to ./cifar10/combAda\Cifar10_.01-0.21-1.04.hdf5
#
# Epoch 2: val_loss did not improve from 1.04205
# Epoch 2: early stopping
#
# After Iter: 24
# 	Loss and Acc: [1.0420527458190918, 0.7314000129699707]
#
# number of data with first and second choice probability lower than 0.01: 126
# number of data with probability higher than 0.9999: 280
# x shape to be added from low margin: (126, 32, 32, 3)
# y shape to be added: (126, 10)
# x shape to be added from high probability: (280, 32, 32, 3)
# y shape to be added: (280, 10)
# new training data:
# 	x: (31473, 32, 32, 3)
# 	y: (31473, 10)
# remaining data:
# 	x: (18527, 32, 32, 3)
# 	y: (18527, 10)
#
# Epoch 1: val_loss improved from inf to 1.04728, saving model to ./cifar10/combAda\Cifar10_.01-0.22-1.05.hdf5
#
# Epoch 2: val_loss did not improve from 1.04728
# Epoch 2: early stopping
#
# After Iter: 25
# 	Loss and Acc: [1.0472787618637085, 0.7282999753952026]
#
# number of data with first and second choice probability lower than 0.01: 112
# number of data with probability higher than 0.9999: 218
# x shape to be added from low margin: (112, 32, 32, 3)
# y shape to be added: (112, 10)
# x shape to be added from high probability: (218, 32, 32, 3)
# y shape to be added: (218, 10)
# new training data:
# 	x: (31803, 32, 32, 3)
# 	y: (31803, 10)
# remaining data:
# 	x: (18197, 32, 32, 3)
# 	y: (18197, 10)
#
# Epoch 1: val_loss improved from inf to 1.08413, saving model to ./cifar10/combAda\Cifar10_.01-0.22-1.08.hdf5
#
# Epoch 2: val_loss did not improve from 1.08413
# Epoch 2: early stopping
#
# After Iter: 26
# 	Loss and Acc: [1.0841336250305176, 0.722100019454956]
#
# number of data with first and second choice probability lower than 0.01: 122
# number of data with probability higher than 0.9999: 216
# x shape to be added from low margin: (122, 32, 32, 3)
# y shape to be added: (122, 10)
# x shape to be added from high probability: (216, 32, 32, 3)
# y shape to be added: (216, 10)
# new training data:
# 	x: (32141, 32, 32, 3)
# 	y: (32141, 10)
# remaining data:
# 	x: (17859, 32, 32, 3)
# 	y: (17859, 10)
#
# Epoch 1: val_loss improved from inf to 1.14001, saving model to ./cifar10/combAda\Cifar10_.01-0.20-1.14.hdf5
#
# Epoch 2: val_loss improved from 1.14001 to 1.13900, saving model to ./cifar10/combAda\Cifar10_.02-0.20-1.14.hdf5
#
# Epoch 3: val_loss did not improve from 1.13900
# Epoch 3: early stopping
#
# After Iter: 27
# 	Loss and Acc: [1.1390032768249512, 0.7161999940872192]
#
# number of data with first and second choice probability lower than 0.01: 138
# number of data with probability higher than 0.9999: 350
# x shape to be added from low margin: (138, 32, 32, 3)
# y shape to be added: (138, 10)
# x shape to be added from high probability: (350, 32, 32, 3)
# y shape to be added: (350, 10)
# new training data:
# 	x: (32629, 32, 32, 3)
# 	y: (32629, 10)
# remaining data:
# 	x: (17371, 32, 32, 3)
# 	y: (17371, 10)
#
# Epoch 1: val_loss improved from inf to 1.09617, saving model to ./cifar10/combAda\Cifar10_.01-0.20-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.09617
# Epoch 2: early stopping
#
# After Iter: 28
# 	Loss and Acc: [1.096166729927063, 0.7293000221252441]
#
# number of data with first and second choice probability lower than 0.01: 115
# number of data with probability higher than 0.9999: 351
# x shape to be added from low margin: (115, 32, 32, 3)
# y shape to be added: (115, 10)
# x shape to be added from high probability: (351, 32, 32, 3)
# y shape to be added: (351, 10)
# new training data:
# 	x: (33095, 32, 32, 3)
# 	y: (33095, 10)
# remaining data:
# 	x: (16905, 32, 32, 3)
# 	y: (16905, 10)
#
# Epoch 1: val_loss improved from inf to 1.12058, saving model to ./cifar10/combAda\Cifar10_.01-0.22-1.12.hdf5
#
# Epoch 2: val_loss did not improve from 1.12058
# Epoch 2: early stopping
#
# After Iter: 29
# 	Loss and Acc: [1.1205812692642212, 0.7305999994277954]

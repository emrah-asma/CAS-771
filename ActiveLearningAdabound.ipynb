# %%
# set Keras backend to Tensorflow
#pip install keras-adabound
import os
import tensorflow as tf

os.environ["KERAS_BACKEND"] = "tensorflow"
kerasBKED = os.environ["KERAS_BACKEND"] 
print(kerasBKED)
# Out:
# tensorflow

# %%
# import
import keras
from keras.models import load_model
from keras_adabound import AdaBound
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, InputLayer
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
import os
import pickle
import numpy as np

# %%
# make saving directory
saveDir = "./cifar10/actAda/"
if not os.path.isdir(saveDir):
    os.makedirs(saveDir)

# %%
# get Cifar10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('x train shape:', x_train.shape)
print(x_train.shape[0], 'training images')
print(x_test.shape[0], 'test images')
# Out:
# x train shape: (50000, 32, 32, 3)
# 50000 training images
# 10000 test images

# %%
from keras.utils import np_utils
# prerequisite
num_classes = 10
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
initNum = 10000
x_train1 = x_train[:initNum]
y_train1 = y_train[:initNum]
remainXTrain = x_train[initNum:]
remainYTrain = y_train[initNum:]

# %%
print("initial training X: {0}\n\
initial training Y: {1}\n\
remaining training X: {2}\n\
remaining training Y: {3}\n\
test X: {4}\n\
test Y: {5}".format(
    x_train1.shape,y_train1.shape,remainXTrain.shape,remainYTrain.shape,x_test.shape,y_test.shape))
# Out:
# initial training X: (10000, 32, 32, 3)
# initial training Y: (10000, 10)
# remaining training X: (40000, 32, 32, 3)
# remaining training Y: (40000, 10)
# test X: (10000, 32, 32, 3)
# test Y: (10000, 10)

# %%
labels = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
from keras_adabound import AdaBound

# optimization and compile
def compileModel(model, lr=1e-3, decay=0.1):
    opt = AdaBound(learning_rate=lr, final_lr=decay)

    model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=['accuracy'])
   
    return model

# %%
# define layers
def getModel(loadModel=False, modelFilePath="", lr=1e-3, decay=0.1):
    model = Sequential()
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    
    model = compileModel(model)
    
    # load model weights if specified
    if loadModel == True:
        model.load_weights(modelFilePath)
    
    return model

# %%
# get the newest model file
def getNewestModel(dirname=saveDir):
    import os
    from glob import glob
    target = os.path.join(dirname, '*')
    files = [(f, os.path.getmtime(f)) for f in glob(target)]
    if len(files) == 0:
        return getModel()
    else:
        newestModel = sorted(files, key=lambda files: files[1])[-1]
        return getModel(True, newestModel[0])

# %%
# get the CNN model
model = getModel()

# %%
# train the model
def trainModel(model, xTrain, yTrain, xTest, yTest, batch_size=50, epochs=100, patience=1):
    es_cb = EarlyStopping(monitor='val_loss', patience=patience, verbose=1, mode='auto')
    chkpt = os.path.join(saveDir, 'Cifar10_.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5')
    cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

    # train
    model.fit(xTrain, yTrain,
              batch_size=batch_size,
              epochs=epochs,
              verbose=0,
              validation_data=(xTest, yTest),
              callbacks=[es_cb, cp_cb],
              shuffle=True)
    return model

# %%
# run training on the initial dataset

model = trainModel(model, x_train1, y_train1, x_test, y_test, patience=2)
# Out:
# Epoch 1: val_loss improved from inf to 1.81861, saving model to ./cifar10/actAda\Cifar10_.01-2.07-1.82.hdf5
#
# Epoch 2: val_loss improved from 1.81861 to 1.56795, saving model to ./cifar10/actAda\Cifar10_.02-1.72-1.57.hdf5
#
# Epoch 3: val_loss improved from 1.56795 to 1.44617, saving model to ./cifar10/actAda\Cifar10_.03-1.52-1.45.hdf5
#
# Epoch 4: val_loss improved from 1.44617 to 1.33431, saving model to ./cifar10/actAda\Cifar10_.04-1.42-1.33.hdf5
#
# Epoch 5: val_loss improved from 1.33431 to 1.32074, saving model to ./cifar10/actAda\Cifar10_.05-1.33-1.32.hdf5
#
# Epoch 6: val_loss improved from 1.32074 to 1.25413, saving model to ./cifar10/actAda\Cifar10_.06-1.25-1.25.hdf5
#
# Epoch 7: val_loss improved from 1.25413 to 1.18925, saving model to ./cifar10/actAda\Cifar10_.07-1.16-1.19.hdf5
#
# Epoch 8: val_loss did not improve from 1.18925
#
# Epoch 9: val_loss improved from 1.18925 to 1.16280, saving model to ./cifar10/actAda\Cifar10_.09-1.02-1.16.hdf5
#
# Epoch 10: val_loss improved from 1.16280 to 1.10931, saving model to ./cifar10/actAda\Cifar10_.10-0.95-1.11.hdf5
#
# Epoch 11: val_loss improved from 1.10931 to 1.09598, saving model to ./cifar10/actAda\Cifar10_.11-0.87-1.10.hdf5
#
# Epoch 12: val_loss improved from 1.09598 to 1.08911, saving model to ./cifar10/actAda\Cifar10_.12-0.84-1.09.hdf5
#
# Epoch 13: val_loss did not improve from 1.08911
#
# Epoch 14: val_loss did not improve from 1.08911
# Epoch 14: early stopping

# %%
# use the pre-trained model, with 65% accuracy on test data

model.load_weights("./cifar10/actAda/Cifar10_.12-0.84-1.09.hdf5")

# %%
# define evaluation method
def evaluate(model, xTest, yTest, display=False):
    # only shows loss and accuracy
    if display == False:
        ev = model.evaluate(xTest, yTest, verbose=0)
        return ev
    # shows confusion matrix, classification report and accuracy score
    else:
        import pandas as pd
        import seaborn as sn
        import matplotlib.pyplot as plt
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import classification_report, accuracy_score

        def toNum(y):
            yNum = []
            for x in y:
                yNum.append(x.argmax())
            return np.array(yNum)

        # visualize confusion matrix on heat map
        def print_cmx(y_true, y_pred):
            labels = sorted(list(set(y_true)))
            cmx_data = confusion_matrix(y_true, y_pred, labels=labels)

            df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)

            plt.figure(figsize = (10,7))
            sn.heatmap(df_cmx, annot=True)
            plt.show()

        # reshape testing target to fit to scikit-learn metric form
        y_testPred = model.predict(xTest)
        y_testP = toNum(y_testPred)
        y_true = toNum(yTest)

        # get confusion matrix, classification report and accuracy score
        print_cmx(y_true, y_testP)
        print(classification_report(y_true, y_testP))
        print("Accuracy: {0}".format(accuracy_score(y_true, y_testP)))

# %%
# evaluate the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.72      0.67      1000
#            1       0.74      0.81      0.77      1000
#            2       0.48      0.49      0.48      1000
#            3       0.46      0.40      0.43      1000
#            4       0.59      0.42      0.49      1000
#            5       0.53      0.53      0.53      1000
#            6       0.62      0.76      0.68      1000
#            7       0.69      0.70      0.69      1000
#            8       0.72      0.77      0.74      1000
#            9       0.76      0.64      0.69      1000
#
#     accuracy                           0.62     10000
#    macro avg       0.62      0.62      0.62     10000
# weighted avg       0.62      0.62      0.62     10000
#
# Accuracy: 0.6234

# %%
# record the loss and accuracy
evalHistory = []
evalHistory.append(evaluate(model, x_test, y_test, display=False))
print(evalHistory[-1])
# Out:
# [1.0891060829162598, 0.6233999729156494]

# %%
# get a list of low margin inference
def getLowMargin(proba, bound=0.01):
    ls = []
    for i in range(len(proba)):
        margin = proba[i][np.argsort(proba[i])][-1] - proba[i][np.argsort(proba[i])][-2]
        if margin < bound:
            ls.append([i,margin])
    return ls

# %%
# concatenate initial training data with low margin of 1st and 2nd choice inference, removing them from remaining data
def concatLowMarginData(proba, remainX, remainY, xTrain, yTrain, bound=0.01):
    lm = getLowMargin(proba, bound)
    print("number of data with first and second choice probability lower than {0}: {1}".format(bound,len(lm)))
    
    nlm = np.array(np.array(lm)[:,0], dtype="int32")
    xAdd = remainX[nlm]
    yAdd = remainY[nlm]
    print("x shape to be added: {0}\ny shape to be added: {1}".format(xAdd.shape, yAdd.shape))
    
    NewXTrain = np.vstack((xTrain, xAdd))
    NewYTrain = np.vstack((yTrain, yAdd))
    print("new training data:\n\tx: {0}\n\ty: {1}".format(NewXTrain.shape, NewYTrain.shape))
    
    remainX2 = np.delete(remainX, nlm, axis=0)
    remainY2 = np.delete(remainY, nlm, axis=0)
    print("remaining data:\n\tx: {0}\n\ty: {1}".format(remainX2.shape, remainY2.shape))
        
    return remainX2, remainY2, NewXTrain, NewYTrain

# %%
# get new training data
# proba = model.predict_proba(remainXTrain, verbose=0)
proba=model.predict(remainXTrain,verbose=0)
remainXTrain, remainYTrain, x_train2, y_train2 = concatLowMarginData(proba, 
                                                                     remainXTrain, 
                                                                     remainYTrain, 
                                                                     x_train1, 
                                                                     y_train1, 
                                                                     0.01)
# Out:
# number of data with first and second choice probability lower than 0.01: 646
# x shape to be added: (646, 32, 32, 3)
# y shape to be added: (646, 10)
# new training data:
# 	x: (10646, 32, 32, 3)
# 	y: (10646, 10)
# remaining data:
# 	x: (39354, 32, 32, 3)
# 	y: (39354, 10)

# %%
# retrain the model
model = trainModel(model, x_train2, y_train2, x_test, y_test)
# Out:
# Epoch 1: val_loss improved from inf to 1.09003, saving model to ./cifar10/actAda\Cifar10_.01-0.84-1.09.hdf5
#
# Epoch 2: val_loss did not improve from 1.09003
# Epoch 2: early stopping

# %%
# load the newest checkpoint model to get the best accuracy one
model = getNewestModel()

# %%
# evaluate with the initial test dataset
evaluate(model, x_test, y_test, display=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.63      0.66      1000
#            1       0.79      0.74      0.77      1000
#            2       0.64      0.33      0.44      1000
#            3       0.40      0.47      0.43      1000
#            4       0.54      0.59      0.56      1000
#            5       0.48      0.60      0.54      1000
#            6       0.67      0.74      0.70      1000
#            7       0.75      0.62      0.68      1000
#            8       0.73      0.78      0.75      1000
#            9       0.67      0.76      0.71      1000
#
#     accuracy                           0.63     10000
#    macro avg       0.64      0.63      0.62     10000
# weighted avg       0.64      0.63      0.62     10000
#
# Accuracy: 0.6266

# %%
# record the loss and accuracy
evalHistory.append(evaluate(model, x_test, y_test, display=False))
print(evalHistory[-1])
# Out:
# [1.0900273323059082, 0.6266000270843506]

# %%
for i in range(30):
    #proba = model.predict_proba(remainXTrain, verbose=0)
    proba=model.predict(remainXTrain,verbose=0)
    remainXTrain, remainYTrain, x_train2, y_train2 = concatLowMarginData(proba, 
                                                                         remainXTrain, 
                                                                         remainYTrain, 
                                                                         x_train2, 
                                                                         y_train2, 
                                                                         0.01)
    model = trainModel(model, x_train2, y_train2, x_test, y_test)
    model = getNewestModel()
    evalHistory.append(evaluate(model, x_test, y_test, display=False))
    print("\nAfter Iter: {0}\n\tLoss and Acc: {1}\n".format(i,evalHistory[-1]))
# Out:
# number of data with first and second choice probability lower than 0.01: 622
# x shape to be added: (622, 32, 32, 3)
# y shape to be added: (622, 10)
# new training data:
# 	x: (11268, 32, 32, 3)
# 	y: (11268, 10)
# remaining data:
# 	x: (38732, 32, 32, 3)
# 	y: (38732, 10)
#
# Epoch 1: val_loss improved from inf to 1.03073, saving model to ./cifar10/actAda\Cifar10_.01-0.95-1.03.hdf5
#
# Epoch 2: val_loss did not improve from 1.03073
# Epoch 2: early stopping
#
# After Iter: 0
# 	Loss and Acc: [1.030730962753296, 0.6355999708175659]
#
# number of data with first and second choice probability lower than 0.01: 634
# x shape to be added: (634, 32, 32, 3)
# y shape to be added: (634, 10)
# new training data:
# 	x: (11902, 32, 32, 3)
# 	y: (11902, 10)
# remaining data:
# 	x: (38098, 32, 32, 3)
# 	y: (38098, 10)
#
# Epoch 1: val_loss improved from inf to 1.04120, saving model to ./cifar10/actAda\Cifar10_.01-0.90-1.04.hdf5
#
# Epoch 2: val_loss improved from 1.04120 to 1.02151, saving model to ./cifar10/actAda\Cifar10_.02-0.73-1.02.hdf5
#
# Epoch 3: val_loss improved from 1.02151 to 1.01480, saving model to ./cifar10/actAda\Cifar10_.03-0.63-1.01.hdf5
#
# Epoch 4: val_loss did not improve from 1.01480
# Epoch 4: early stopping
#
# After Iter: 1
# 	Loss and Acc: [1.014801263809204, 0.6646000146865845]
#
# number of data with first and second choice probability lower than 0.01: 431
# x shape to be added: (431, 32, 32, 3)
# y shape to be added: (431, 10)
# new training data:
# 	x: (12333, 32, 32, 3)
# 	y: (12333, 10)
# remaining data:
# 	x: (37667, 32, 32, 3)
# 	y: (37667, 10)
#
# Epoch 1: val_loss improved from inf to 1.04833, saving model to ./cifar10/actAda\Cifar10_.01-0.68-1.05.hdf5
#
# Epoch 2: val_loss improved from 1.04833 to 1.03336, saving model to ./cifar10/actAda\Cifar10_.02-0.55-1.03.hdf5
#
# Epoch 3: val_loss did not improve from 1.03336
# Epoch 3: early stopping
#
# After Iter: 2
# 	Loss and Acc: [1.0333585739135742, 0.6638000011444092]
#
# number of data with first and second choice probability lower than 0.01: 384
# x shape to be added: (384, 32, 32, 3)
# y shape to be added: (384, 10)
# new training data:
# 	x: (12717, 32, 32, 3)
# 	y: (12717, 10)
# remaining data:
# 	x: (37283, 32, 32, 3)
# 	y: (37283, 10)
#
# Epoch 1: val_loss improved from inf to 1.05767, saving model to ./cifar10/actAda\Cifar10_.01-0.59-1.06.hdf5
#
# Epoch 2: val_loss improved from 1.05767 to 1.04404, saving model to ./cifar10/actAda\Cifar10_.02-0.46-1.04.hdf5
#
# Epoch 3: val_loss did not improve from 1.04404
# Epoch 3: early stopping
#
# After Iter: 3
# 	Loss and Acc: [1.0440424680709839, 0.6787999868392944]
#
# number of data with first and second choice probability lower than 0.01: 299
# x shape to be added: (299, 32, 32, 3)
# y shape to be added: (299, 10)
# new training data:
# 	x: (13016, 32, 32, 3)
# 	y: (13016, 10)
# remaining data:
# 	x: (36984, 32, 32, 3)
# 	y: (36984, 10)
#
# Epoch 1: val_loss improved from inf to 1.08994, saving model to ./cifar10/actAda\Cifar10_.01-0.49-1.09.hdf5
#
# Epoch 2: val_loss did not improve from 1.08994
# Epoch 2: early stopping
#
# After Iter: 4
# 	Loss and Acc: [1.0899444818496704, 0.6725000143051147]
#
# number of data with first and second choice probability lower than 0.01: 304
# x shape to be added: (304, 32, 32, 3)
# y shape to be added: (304, 10)
# new training data:
# 	x: (13320, 32, 32, 3)
# 	y: (13320, 10)
# remaining data:
# 	x: (36680, 32, 32, 3)
# 	y: (36680, 10)
#
# Epoch 1: val_loss improved from inf to 1.06346, saving model to ./cifar10/actAda\Cifar10_.01-0.48-1.06.hdf5
#
# Epoch 2: val_loss did not improve from 1.06346
# Epoch 2: early stopping
#
# After Iter: 5
# 	Loss and Acc: [1.063455581665039, 0.6822999715805054]
#
# number of data with first and second choice probability lower than 0.01: 285
# x shape to be added: (285, 32, 32, 3)
# y shape to be added: (285, 10)
# new training data:
# 	x: (13605, 32, 32, 3)
# 	y: (13605, 10)
# remaining data:
# 	x: (36395, 32, 32, 3)
# 	y: (36395, 10)
#
# Epoch 1: val_loss improved from inf to 1.03718, saving model to ./cifar10/actAda\Cifar10_.01-0.46-1.04.hdf5
#
# Epoch 2: val_loss did not improve from 1.03718
# Epoch 2: early stopping
#
# After Iter: 6
# 	Loss and Acc: [1.037177562713623, 0.6746000051498413]
#
# number of data with first and second choice probability lower than 0.01: 305
# x shape to be added: (305, 32, 32, 3)
# y shape to be added: (305, 10)
# new training data:
# 	x: (13910, 32, 32, 3)
# 	y: (13910, 10)
# remaining data:
# 	x: (36090, 32, 32, 3)
# 	y: (36090, 10)
#
# Epoch 1: val_loss improved from inf to 1.04438, saving model to ./cifar10/actAda\Cifar10_.01-0.46-1.04.hdf5
#
# Epoch 2: val_loss did not improve from 1.04438
# Epoch 2: early stopping
#
# After Iter: 7
# 	Loss and Acc: [1.0443830490112305, 0.6858999729156494]
#
# number of data with first and second choice probability lower than 0.01: 261
# x shape to be added: (261, 32, 32, 3)
# y shape to be added: (261, 10)
# new training data:
# 	x: (14171, 32, 32, 3)
# 	y: (14171, 10)
# remaining data:
# 	x: (35829, 32, 32, 3)
# 	y: (35829, 10)
#
# Epoch 1: val_loss improved from inf to 1.04702, saving model to ./cifar10/actAda\Cifar10_.01-0.43-1.05.hdf5
#
# Epoch 2: val_loss did not improve from 1.04702
# Epoch 2: early stopping
#
# After Iter: 8
# 	Loss and Acc: [1.0470199584960938, 0.6941999793052673]
#
# number of data with first and second choice probability lower than 0.01: 233
# x shape to be added: (233, 32, 32, 3)
# y shape to be added: (233, 10)
# new training data:
# 	x: (14404, 32, 32, 3)
# 	y: (14404, 10)
# remaining data:
# 	x: (35596, 32, 32, 3)
# 	y: (35596, 10)
#
# Epoch 1: val_loss improved from inf to 1.13942, saving model to ./cifar10/actAda\Cifar10_.01-0.41-1.14.hdf5
#
# Epoch 2: val_loss improved from 1.13942 to 1.13540, saving model to ./cifar10/actAda\Cifar10_.02-0.33-1.14.hdf5
#
# Epoch 3: val_loss did not improve from 1.13540
# Epoch 3: early stopping
#
# After Iter: 9
# 	Loss and Acc: [1.1353973150253296, 0.6880000233650208]
#
# number of data with first and second choice probability lower than 0.01: 215
# x shape to be added: (215, 32, 32, 3)
# y shape to be added: (215, 10)
# new training data:
# 	x: (14619, 32, 32, 3)
# 	y: (14619, 10)
# remaining data:
# 	x: (35381, 32, 32, 3)
# 	y: (35381, 10)
#
# Epoch 1: val_loss improved from inf to 1.07797, saving model to ./cifar10/actAda\Cifar10_.01-0.36-1.08.hdf5
#
# Epoch 2: val_loss did not improve from 1.07797
# Epoch 2: early stopping
#
# After Iter: 10
# 	Loss and Acc: [1.077970027923584, 0.691100001335144]
#
# number of data with first and second choice probability lower than 0.01: 210
# x shape to be added: (210, 32, 32, 3)
# y shape to be added: (210, 10)
# new training data:
# 	x: (14829, 32, 32, 3)
# 	y: (14829, 10)
# remaining data:
# 	x: (35171, 32, 32, 3)
# 	y: (35171, 10)
#
# Epoch 1: val_loss improved from inf to 1.06661, saving model to ./cifar10/actAda\Cifar10_.01-0.35-1.07.hdf5
#
# Epoch 2: val_loss did not improve from 1.06661
# Epoch 2: early stopping
#
# After Iter: 11
# 	Loss and Acc: [1.0666067600250244, 0.6995999813079834]
#
# number of data with first and second choice probability lower than 0.01: 198
# x shape to be added: (198, 32, 32, 3)
# y shape to be added: (198, 10)
# new training data:
# 	x: (15027, 32, 32, 3)
# 	y: (15027, 10)
# remaining data:
# 	x: (34973, 32, 32, 3)
# 	y: (34973, 10)
#
# Epoch 1: val_loss improved from inf to 1.12563, saving model to ./cifar10/actAda\Cifar10_.01-0.34-1.13.hdf5
#
# Epoch 2: val_loss did not improve from 1.12563
# Epoch 2: early stopping
#
# After Iter: 12
# 	Loss and Acc: [1.125626802444458, 0.6962000131607056]
#
# number of data with first and second choice probability lower than 0.01: 201
# x shape to be added: (201, 32, 32, 3)
# y shape to be added: (201, 10)
# new training data:
# 	x: (15228, 32, 32, 3)
# 	y: (15228, 10)
# remaining data:
# 	x: (34772, 32, 32, 3)
# 	y: (34772, 10)
#
# Epoch 1: val_loss improved from inf to 1.14705, saving model to ./cifar10/actAda\Cifar10_.01-0.34-1.15.hdf5
#
# Epoch 2: val_loss did not improve from 1.14705
# Epoch 2: early stopping
#
# After Iter: 13
# 	Loss and Acc: [1.1470496654510498, 0.6901000142097473]
#
# number of data with first and second choice probability lower than 0.01: 166
# x shape to be added: (166, 32, 32, 3)
# y shape to be added: (166, 10)
# new training data:
# 	x: (15394, 32, 32, 3)
# 	y: (15394, 10)
# remaining data:
# 	x: (34606, 32, 32, 3)
# 	y: (34606, 10)
#
# Epoch 1: val_loss improved from inf to 1.11726, saving model to ./cifar10/actAda\Cifar10_.01-0.32-1.12.hdf5
#
# Epoch 2: val_loss did not improve from 1.11726
# Epoch 2: early stopping
#
# After Iter: 14
# 	Loss and Acc: [1.117258071899414, 0.6995000243186951]
# number of data with first and second choice probability lower than 0.01: 168
# x shape to be added: (168, 32, 32, 3)
# y shape to be added: (168, 10)
# new training data:
# 	x: (15562, 32, 32, 3)
# 	y: (15562, 10)
# remaining data:
# 	x: (34438, 32, 32, 3)
# 	y: (34438, 10)
#
# Epoch 1: val_loss improved from inf to 1.08663, saving model to ./cifar10/actAda\Cifar10_.01-0.31-1.09.hdf5
#
# Epoch 2: val_loss did not improve from 1.08663
# Epoch 2: early stopping
#
# After Iter: 15
# 	Loss and Acc: [1.0866341590881348, 0.6980000138282776]
#
# number of data with first and second choice probability lower than 0.01: 173
# x shape to be added: (173, 32, 32, 3)
# y shape to be added: (173, 10)
# new training data:
# 	x: (15735, 32, 32, 3)
# 	y: (15735, 10)
# remaining data:
# 	x: (34265, 32, 32, 3)
# 	y: (34265, 10)
#
# Epoch 1: val_loss improved from inf to 1.06133, saving model to ./cifar10/actAda\Cifar10_.01-0.31-1.06.hdf5
#
# Epoch 2: val_loss did not improve from 1.06133
# Epoch 2: early stopping
#
# After Iter: 16
# 	Loss and Acc: [1.0613256692886353, 0.7014999985694885]
#
# number of data with first and second choice probability lower than 0.01: 159
# x shape to be added: (159, 32, 32, 3)
# y shape to be added: (159, 10)
# new training data:
# 	x: (15894, 32, 32, 3)
# 	y: (15894, 10)
# remaining data:
# 	x: (34106, 32, 32, 3)
# 	y: (34106, 10)
#
# Epoch 1: val_loss improved from inf to 1.05093, saving model to ./cifar10/actAda\Cifar10_.01-0.31-1.05.hdf5
#
# Epoch 2: val_loss did not improve from 1.05093
# Epoch 2: early stopping
#
# After Iter: 17
# 	Loss and Acc: [1.0509276390075684, 0.7045999765396118]
#
# number of data with first and second choice probability lower than 0.01: 189
# x shape to be added: (189, 32, 32, 3)
# y shape to be added: (189, 10)
# new training data:
# 	x: (16083, 32, 32, 3)
# 	y: (16083, 10)
# remaining data:
# 	x: (33917, 32, 32, 3)
# 	y: (33917, 10)
#
# Epoch 1: val_loss improved from inf to 1.07830, saving model to ./cifar10/actAda\Cifar10_.01-0.30-1.08.hdf5
#
# Epoch 2: val_loss did not improve from 1.07830
# Epoch 2: early stopping
#
# After Iter: 18
# 	Loss and Acc: [1.0783029794692993, 0.7063000202178955]
#
# number of data with first and second choice probability lower than 0.01: 139
# x shape to be added: (139, 32, 32, 3)
# y shape to be added: (139, 10)
# new training data:
# 	x: (16222, 32, 32, 3)
# 	y: (16222, 10)
# remaining data:
# 	x: (33778, 32, 32, 3)
# 	y: (33778, 10)
#
# Epoch 1: val_loss improved from inf to 1.11249, saving model to ./cifar10/actAda\Cifar10_.01-0.31-1.11.hdf5
#
# Epoch 2: val_loss did not improve from 1.11249
# Epoch 2: early stopping
#
# After Iter: 19
# 	Loss and Acc: [1.1124935150146484, 0.7070000171661377]
#
# number of data with first and second choice probability lower than 0.01: 143
# x shape to be added: (143, 32, 32, 3)
# y shape to be added: (143, 10)
# new training data:
# 	x: (16365, 32, 32, 3)
# 	y: (16365, 10)
# remaining data:
# 	x: (33635, 32, 32, 3)
# 	y: (33635, 10)
#
# Epoch 1: val_loss improved from inf to 1.10199, saving model to ./cifar10/actAda\Cifar10_.01-0.29-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.10199
# Epoch 2: early stopping
#
# After Iter: 20
# 	Loss and Acc: [1.101985216140747, 0.7006000280380249]
#
# number of data with first and second choice probability lower than 0.01: 162
# x shape to be added: (162, 32, 32, 3)
# y shape to be added: (162, 10)
# new training data:
# 	x: (16527, 32, 32, 3)
# 	y: (16527, 10)
# remaining data:
# 	x: (33473, 32, 32, 3)
# 	y: (33473, 10)
#
# Epoch 1: val_loss improved from inf to 1.05294, saving model to ./cifar10/actAda\Cifar10_.01-0.29-1.05.hdf5
#
# Epoch 2: val_loss did not improve from 1.05294
# Epoch 2: early stopping
#
# After Iter: 21
# 	Loss and Acc: [1.052944540977478, 0.7042999863624573]
#
# number of data with first and second choice probability lower than 0.01: 160
# x shape to be added: (160, 32, 32, 3)
# y shape to be added: (160, 10)
# new training data:
# 	x: (16687, 32, 32, 3)
# 	y: (16687, 10)
# remaining data:
# 	x: (33313, 32, 32, 3)
# 	y: (33313, 10)
#
# Epoch 1: val_loss improved from inf to 1.09596, saving model to ./cifar10/actAda\Cifar10_.01-0.28-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.09596
# Epoch 2: early stopping
#
# After Iter: 22
# 	Loss and Acc: [1.0959573984146118, 0.6970999836921692]
#
# number of data with first and second choice probability lower than 0.01: 175
# x shape to be added: (175, 32, 32, 3)
# y shape to be added: (175, 10)
# new training data:
# 	x: (16862, 32, 32, 3)
# 	y: (16862, 10)
# remaining data:
# 	x: (33138, 32, 32, 3)
# 	y: (33138, 10)
#
# Epoch 1: val_loss improved from inf to 1.06948, saving model to ./cifar10/actAda\Cifar10_.01-0.28-1.07.hdf5
#
# Epoch 2: val_loss did not improve from 1.06948
# Epoch 2: early stopping
#
# After Iter: 23
# 	Loss and Acc: [1.0694804191589355, 0.7063999772071838]
#
# number of data with first and second choice probability lower than 0.01: 151
# x shape to be added: (151, 32, 32, 3)
# y shape to be added: (151, 10)
# new training data:
# 	x: (17013, 32, 32, 3)
# 	y: (17013, 10)
# remaining data:
# 	x: (32987, 32, 32, 3)
# 	y: (32987, 10)
#
# Epoch 1: val_loss improved from inf to 1.13362, saving model to ./cifar10/actAda\Cifar10_.01-0.29-1.13.hdf5
#
# Epoch 2: val_loss did not improve from 1.13362
# Epoch 2: early stopping
#
# After Iter: 24
# 	Loss and Acc: [1.1336219310760498, 0.6996999979019165]
#
# number of data with first and second choice probability lower than 0.01: 191
# x shape to be added: (191, 32, 32, 3)
# y shape to be added: (191, 10)
# new training data:
# 	x: (17204, 32, 32, 3)
# 	y: (17204, 10)
# remaining data:
# 	x: (32796, 32, 32, 3)
# 	y: (32796, 10)
#
# Epoch 1: val_loss improved from inf to 1.12349, saving model to ./cifar10/actAda\Cifar10_.01-0.28-1.12.hdf5
#
# Epoch 2: val_loss did not improve from 1.12349
# Epoch 2: early stopping
#
# After Iter: 25
# 	Loss and Acc: [1.1234899759292603, 0.7010999917984009]
#
# number of data with first and second choice probability lower than 0.01: 155
# x shape to be added: (155, 32, 32, 3)
# y shape to be added: (155, 10)
# new training data:
# 	x: (17359, 32, 32, 3)
# 	y: (17359, 10)
# remaining data:
# 	x: (32641, 32, 32, 3)
# 	y: (32641, 10)
#
# Epoch 1: val_loss improved from inf to 1.07521, saving model to ./cifar10/actAda\Cifar10_.01-0.28-1.08.hdf5
#
# Epoch 2: val_loss did not improve from 1.07521
# Epoch 2: early stopping
#
# After Iter: 26
# 	Loss and Acc: [1.0752058029174805, 0.704800009727478]
#
# number of data with first and second choice probability lower than 0.01: 141
# x shape to be added: (141, 32, 32, 3)
# y shape to be added: (141, 10)
# new training data:
# 	x: (17500, 32, 32, 3)
# 	y: (17500, 10)
# remaining data:
# 	x: (32500, 32, 32, 3)
# 	y: (32500, 10)
#
# Epoch 1: val_loss improved from inf to 1.10423, saving model to ./cifar10/actAda\Cifar10_.01-0.26-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.10423
# Epoch 2: early stopping
#
# After Iter: 27
# 	Loss and Acc: [1.1042349338531494, 0.7081999778747559]
#
# number of data with first and second choice probability lower than 0.01: 139
# x shape to be added: (139, 32, 32, 3)
# y shape to be added: (139, 10)
# new training data:
# 	x: (17639, 32, 32, 3)
# 	y: (17639, 10)
# remaining data:
# 	x: (32361, 32, 32, 3)
# 	y: (32361, 10)
#
# Epoch 1: val_loss improved from inf to 1.09912, saving model to ./cifar10/actAda\Cifar10_.01-0.27-1.10.hdf5
#
# Epoch 2: val_loss did not improve from 1.09912
# Epoch 2: early stopping
#
# After Iter: 28
# 	Loss and Acc: [1.0991175174713135, 0.7139000296592712]
#
# number of data with first and second choice probability lower than 0.01: 124
# x shape to be added: (124, 32, 32, 3)
# y shape to be added: (124, 10)
# new training data:
# 	x: (17763, 32, 32, 3)
# 	y: (17763, 10)
# remaining data:
# 	x: (32237, 32, 32, 3)
# 	y: (32237, 10)
#
# Epoch 1: val_loss improved from inf to 1.06496, saving model to ./cifar10/actAda\Cifar10_.01-0.28-1.06.hdf5
#
# Epoch 2: val_loss did not improve from 1.06496
# Epoch 2: early stopping
#
# After Iter: 29
# 	Loss and Acc: [1.0649577379226685, 0.7039999961853027]
